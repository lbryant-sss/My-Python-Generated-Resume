# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np
import datetime
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg



#Some text variables 
title = "This resume is generated using def __python():.\n"
name = 'Brian Mungai'
cv = 'CURRICULUM VITAE'
career = 'Software Engineer'
email = 'Email: brianmungai350@gmail.com'
tel = 'Tel: +2547 43212 987'
github = 'Github: github.com/lbryant-sss'
education = 'Education'
inst = 'Egerton University'
programme = 'BSc. Physics'
since = '2018'
projects = 'Projects'
first = 'Django Websites'
first_desc = "I have built two websites based on Python's web development framework, Django: A blogging app and my\nportfolio. Some functionality I built on them are emailing, creating, updating and accessing database\ninformation."
second = 'Python'
sec_desc = 'I have worked on some python projects using various libraries.\n\n  -  First, web scrapping using BeautifulSoup and htmllib, through which I made scripts that scrap data from\n     websites, and generate dataframes that can be processed and visualized.\n\n  -  Second, this cv is generated using python, matplotlib.backends to generate a pdf and matplotlib to\n     annotate the text and style them.\n\n  -  Third, I have also worked on data analysis projects which basically involves opening files, reading the data\n     using numpy and visualizing the data using matplotlib. One such project is visualizing bitcoin prices from\n     csv data.\n\nThe code to this projects can be found on my github profile repositories.'
skills = 'Skills'
one = "Python's Django Framework"
two = 'RESTFull APIs'
four = 'Javascript'
five = 'Postgresql'
three = 'CSS, HTML'
lang = 'Languages'
english = 'English'
prof = '  -  Full professional proficiency.'
swahili = 'Swahili'
prof2 = '  -  Full professional proficiency.'
interests = 'Interests'
int1 = 'Cyber Security'
int2 = 'Machine Learning/ Artificial intelligence'

# %matplotlib inline
#Setting the font
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

#ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0,
#linewidth=50)
#plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
#plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)
#plt.axis('off')
grey = '#2e2e2d'
fig, ax = plt.subplots(figsize=(10, 14.5))
plt.annotate(title, (.1,.98), weight='regular', fontsize=9,
alpha=.75, color='#000000')
plt.annotate(name, (0.01, 0.97), weight='bold', fontsize=22, color='#144e89')
plt.annotate(career, (0.01, .95), weight='regular', fontsize=12, color='#144e89')
plt.annotate(cv, (0.01,.93), weight='bold', fontsize=10, color='#144e89')
#plt.annotate(email, (0.07, 0.91), weight='regular', fontsize=10, color=grey)
#plt.annotate(tel, (0.43, 0.91), weight='regular', fontsize=10, color=grey)
#plt.annotate(github, (0.7, 0.91), weight='regular', fontsize=10, color=grey)
arr_code = mpimg.imread('Desktop/conts.png')
imagebox = OffsetImage(arr_code, zoom=0.55)
ab = AnnotationBbox(imagebox, (0.5, 0.892))
ax.add_artist(ab)

plt.annotate(projects, (0.01, 0.83), weight='bold', fontsize='14', color='#144e89')

plt.annotate(first, (0.01, 0.8), weight='bold', fontsize='13', color='#14416e')
plt.annotate(first_desc, (0.01, 0.74), weight='regular', fontsize='12', color=grey)

plt.annotate(second, (0.01, 0.7), weight='bold', fontsize=13, color='#14416e')
plt.annotate(sec_desc, (0.01, 0.47), weight='regular', fontsize='12')

plt.annotate(skills, (0.01, 0.44), weight='bold', fontsize=13, color='#144e89')
#plt.annotate(one, (0.01, 0.46), weight='regular', fontsize='12')
#plt.annotate(two, (0.01, 0.44), weight='regular', fontsize='12')
#plt.annotate(three, (0.01, 0.42), weight='regular', fontsize='12')
#plt.annotate(four, (0.01, 0.40), weight='regular', fontsize='12')
#plt.annotate(five, (0.01, 0.38), weight='regular', fontsize='12')
arr_code = mpimg.imread('Desktop/skills.png')
imagebox = OffsetImage(arr_code, zoom=0.55)
ab = AnnotationBbox(imagebox, (0.26, 0.34))
ax.add_artist(ab)



plt.annotate(education, (0.01, 0.2), weight='bold', fontsize='14', color='#144e89')
plt.annotate(inst, (0.01, 0.18), weight='bold', fontsize='13', color='#14416e')
plt.annotate(programme, (0.01, 0.16), weight='regular', fontsize='12', color=grey)
plt.annotate(since, (0.01, 0.14), weight='regular', fontsize=10, color=grey)

plt.annotate(lang, (0.01, 0.115), weight='bold', fontsize='14', color='#144e89')
plt.annotate(english, (0.01, 0.09), weight='bold', fontsize='12', color='#14416e')
plt.annotate(prof, (0.12, 0.09), weight='regular', fontsize='12', color=grey)
plt.annotate(swahili, (0.01, 0.07), weight='bold', fontsize='12', color='#14416e')
plt.annotate(prof2, (0.12, 0.07), weight='regular', fontsize='12', color=grey)


plt.annotate(interests, (0.01, 0.03), weight='bold', fontsize='14', color='#144e89')
plt.annotate(int1, (0.01, 0.015), weight='regular', fontsize='12', color=grey)
plt.annotate(int2, (0.01, 0.000), weight='regular', fontsize='12', color=grey)
#Set the body background color to rgb(82, 86, 89);

plt.axis('off')

plt.savefig("C:/Users/Toshiba/Desktop/Brian'sPyGenerated.pdf", dpi=300, bbox_inches='tight')
