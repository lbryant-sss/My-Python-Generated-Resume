# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np
import datetime
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg



#Some text variables 
title = "This resume is generated using def __python():.\n"
name = 'Brian Mungai'
cv = 'CURRICULUM VITAE'
career = 'Software Engineer'
email = 'Email: brianmungai350@gmail.com'
tel = 'Tel: +2547 43212 987'
github = 'Github: github.com/lbryant-sss'
education = 'EDUCATION'
inst = 'Egerton University,'
programme = 'BSc. Physics'
loc = 'Njoro Ke'
since = 'Joined 2018'
second = 'Python'
skills = 'SKILLS'
skill_category1 = 'Expert: '
skill_category2 = 'Working Knowledge: '
py = 'Python, Django, Bootstrap, HTML,\nCSS, Git Version Control.'
#two = 'RESTFull APIs'
db = 'Postgresql, Javascript(EC6)'
experience = 'WORKING EXPERIENCE'
company = 'RoyalState Insurance Agency'
post = 'Software Engineer'
job_duration = '2020 - 2022, Nairobi Ke'
job = " - Designed the frontend and backend systems\n   for the company's web app which was meant\n   to be a platform where users would learn about\n   insurance policies.\n\n - Built and maintained software application\n   (the web app)using Python (Django).\n\n - Deployed the application to a virtual\n   server."
company1 = 'Nextlink Cyber Cafe'
post1 = 'Cyber Cafe Customer Service'
duration = 'Nov 2019 - April 2020, Nairobi Ke'
cyber = ' - Incharge of maintaining, troubleshooting\n   technical issues upgrading computer software\n   in the shop.\n\n - Assiting customers with PC maintainance and\n   repairs.'
objs = 'CAREER OBJECTIVES'
objectives = 'Overtime I have focused on\nbecoming a better software\nengineer. Enthusiatic problem\nsolver and strong communication\nskills make me motivated to\nlearn more and refine my skills.\nChallanging projects will make\nme better and be a great way to\nprove my value at a company\nlike <company name>.\nI have worked on my projects\nindependently which I enjoy but\nwould also love to be on a\ncollaborative team.'
project = 'Rocket Nozzle Dimensions Calculator'
more_on_project = " - Built a fullstack webapp that allows users to come\n   up with the best rocket nozzle dimensions when\n   designing a rocket, based on NASA's standards.\n\n - The program calculates the nozzle dimensions\n   and other useful parameters, shows the results\n   then generates a downloadable pdf copy of the\n   data.\n\n - It is built on HTML, CSS, django for the\n   backend and bootstrap framework for the frontend.\n   Code can be found on my github profile repository."
lang = 'Languages'
english = 'English'
prof = '  -  Full professional proficiency.'
swahili = 'Swahili'
prof2 = '  -  Full professional proficiency.'
interests = 'INTERESTS'
int1 = 'Cyber Security, Machine\nLearning and Electronics.'
note = '> This resume was genrated using python.'

# %matplotlib inline
#Setting the font
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
grey = '#2e2e2d'
fig, ax = plt.subplots(figsize=(9.85, 14.8))
#plt.annotate(title, (.1,.98), weight='regular', fontsize=9, alpha=.75, color='#000000')
plt.annotate(name, (0.01, 0.97), weight='regular', fontsize=25, color='#ffffff')##144e89
plt.annotate(career, (0.01, .95), weight='regular', fontsize=12, color='#ffffff')
arr_code = mpimg.imread('C:/Users/Toshiba/Desktop/Portfolio Projects/resume/contacts.png')
imagebox = OffsetImage(arr_code, zoom=0.55)
ab = AnnotationBbox(imagebox, (0.51, 0.917))
ax.add_artist(ab)

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.1, color='#000000', alpha=0.8, linewidth=310)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

#SKILL SECTION
plt.annotate(skills, (0.01, 0.86), weight='regular', fontsize=14.5, color='#ffffff')
plt.annotate(skill_category1, (0.01, 0.84), weight='regular', fontsize=13, color='orange')
plt.annotate(py, (0.01, 0.80), weight='regular', fontsize=12, color='#ffffff')

plt.annotate(skill_category2, (0.01, 0.77), weight='regular', fontsize=13, color='orange')
plt.annotate(db, (0.01, 0.75), weight='regular', fontsize=12, color='#ffffff')
#EXPERIENCE
ax.text(0.5, 0.86, 'WORKING EXPERIENCE', color='white', fontsize=15, bbox=dict(facecolor='black', edgecolor='black', boxstyle='round, pad=0.25'))
plt.annotate(company, (0.4, 0.83), weight='regular', fontsize=13, color='brown')
plt.annotate(post, (0.4, 0.815), weight='regular', fontsize=10, color='grey')
plt.annotate(job_duration, (0.4, 0.80), weight='regular', fontsize=10, color='grey')
plt.annotate(job, (0.4, 0.61), weight='regular', fontsize=12, color='black')
plt.annotate(company1, (0.4, 0.57), weight='regular', fontsize=13, color='brown')
plt.annotate(post1, (0.4, 0.555), weight='regular', fontsize=10, color='grey')
plt.annotate(duration, (0.4, 0.54), weight='regular', fontsize=10, color='grey')
plt.annotate(cyber, (0.4, 0.43), weight='regular', fontsize=12, color='black')


#EDUCATION
plt.annotate(education, (0.01, 0.65), weight='regular', fontsize=14.5, color='#ffffff')
plt.annotate(inst, (0.01, 0.63), weight='regular', fontsize=12, color='#ffffff')
plt.annotate(loc, (0.225, 0.63), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(programme, (0.01, 0.61), weight='regular', fontsize=12, color='#ffffff')
plt.annotate(since, (0.01, 0.59), weight='regular', fontsize=9, color='#ffffff')

#CAREER OBJ
#Edit the 'objectives' position vectors before running
plt.annotate(objs, (0.01, 0.53), weight='regular', fontsize=14.5, color='#ffffff')
plt.annotate(objectives, (0.01, 0.29), weight='regular', fontsize=12, color='#ffffff')

#PROJECTS
ax.text(0.5, 0.39, 'PROJECTS', color='white', fontsize=15, bbox=dict(facecolor='black', edgecolor='black', boxstyle='round, pad=0.25'))
plt.annotate(project, (0.4, 0.36), weight='regular', fontsize=13, color='brown')
plt.annotate(more_on_project, (0.4, 0.15), weight='regular', fontsize=12, color='black')
#Edit the 'more_on_project' position vectors before running

#INTERESTS
plt.annotate(interests, (0.01, 0.22), weight='regular', fontsize=14.5, color='#ffffff')
plt.annotate(int1, (0.01, 0.18), weight='regular', fontsize=12, color='#ffffff')

#SIDE NOTE
plt.annotate(note, (0.005, 0.015), weight='regular', fontsize=7, color='#ffffff')

plt.axis('off')

plt.savefig("C:/Users/Toshiba/Desktop/Brian'sResume.pdf", dpi=300, bbox_inches='tight')
